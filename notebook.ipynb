# %%
print("hi")
# Out:
# hi

# %%
import json

with open('sometthing.json', 'r') as f:
    data = json.load(f)

# %%
import json


with open('sometthing.json', 'r') as f:
    data = json.load(f)

html1 = data['pages'][0]['html']

with open('test_original.html', 'w') as f:
    f.write(html1)

# %%
import json

with open('test_single_step_results.json', 'r') as f:
    data = json.load(f)

html1 = data['optimized_html']

with open('test_optimized.html', 'w') as f:
    f.write(html1)

# %%
import requests

with open('webSiteData.html', 'r') as f:
    html_content = f.read()




url = 'https://r.jina.ai/'
new_url = 'www.ddd.com'
headers = {
    'Authorization': 'Bearer jina_08ef8da6068d4042b44a66286a67cf3dqne6ZOey1zK_kL-zqX6NSh-EdbN2',
    'Content-Type': 'application/json',
}
data = {
    'url': new_url,
    'html': html_content
}

response = requests.post(url, headers=headers, json=data)
print(response.text)
# Out:
# Title: Random HTML Page
#
# URL Source: http://www.ddd.com/
#
# Markdown Content:
# Random HTML Page
#
# ...
#
# Welcome to Your Random Page
# ...
#
# *   [🏠 Home](http://www.ddd.com/#)
# *   [📖 About](http://www.ddd.com/#)
# *   [✉️ Contact](http://www.ddd.com/#)
#
# About This Page
# ---------------
#
# This page was generated at random. It demonstrates common HTML elements: headings, lists, cards, images, and a contact form—all styled with simple CSS.
#
# Features List
# -------------
#
# *   Responsive grid of cards
# *   Placeholder images
# *   Simple, clean styling
# *   Contact form at the bottom
#
# Image Gallery
# -------------
#
# ![Image 1: Placeholder 1](https://via.placeholder.com/400x250?text=Image+1)
#
# ### Sample Card 1
#
# This is a randomly generated description for the first card.
#
# ![Image 2: Placeholder 2](https://via.placeholder.com/400x250?text=Image+2)
#
# ### Sample Card 2
#
# This is a randomly generated description for the second card.
#
# ...
